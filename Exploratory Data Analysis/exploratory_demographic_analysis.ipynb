# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
from google.colab import drive
sns.set_style("white")

# %%
# Mount Google Drive
mount_dir = os.path.join('/content','gdrive')
drive.mount(mount_dir)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# Set working directory
os.chdir(os.path.join(mount_dir,'MyDrive','DSCI400','Exploratory Data Analysis')) 
home_dir = os.path.join(mount_dir,'MyDrive','DSCI400')

# %%
# Import apis
import demographic_api as dmg_api

# %%
# Load raw demographic dataset
coswara = pd.read_csv(os.path.join(home_dir,'Coswara-Data-master','Coswara-Data-master','combined_data.csv'), index_col = 'id')
coughvid = pd.read_csv(os.path.join(home_dir,'New Audio','metadata_compiled.csv'),index_col = 'uuid')

# %%
# Create covid labels for coswara dataset
coswara = dmg_api.status_regroup(coswara)
coswara = dmg_api.covid_labels(coswara)

# %%
# Set sns style
dmg_api.set_sns(300,12,15,15)

# %%
# Plot covid status distribution in coswara dataset
dmg_api.covid_bar("coswara",coswara)

# %%
# Plot covid status distribution in coughvid dataset
dmg_api.covid_bar("coughvid",coughvid)

# %%
# Plot age distribution by gender in coswara dataset
dmg_api.age_hist("coswara",coswara)

# %%
# Plot age distribution by gender in coughvid dataset
dmg_api.age_hist("coughvid",coughvid)

# %%
# Plot frequency of symptoms by covid status in coswara dataset
dmg_api.symptom_plot("coswara",coswara)

# %%
# Plot logistic regression of mask usage on covid status

# Reset style
dmg_api.set_sns(300,20,25,25)
dmg_api.covid_mask_reg("coswara",coswara)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
